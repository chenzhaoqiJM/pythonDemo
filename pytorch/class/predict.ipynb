# %%
# License: BSD
# Author: Sasank Chilamkurthy

from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

plt.ion()   # interactive mode

# %%
transform = transforms.Compose([
        transforms.Resize(224),
        # transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

# %% [markdown]
# 加载图片并转成训练过程的格式

# %%
from PIL import Image
img=Image.open('E:/datasets/tire_dataset/leb/leb_1.jpg')
tensorImg = transform(img)

# %%
# batch = convert_image_dtype(tensorImg, dtype=torch.float) #将uint像素值归一化到0-1 float
batch = tensorImg
batch = batch.reshape([1, batch.shape[0], batch.shape[1], batch.shape[2]]) 
print(batch.shape)

# %% [markdown]
# 开始加载模型并预测

# %%
#直接加载模型resnet18
model = torch.load('C:\\Users\\hp\\Desktop\\model_resnet18.pth', map_location=torch.device('cpu'))
model.eval()   # Set model to evaluate mode
output = model(batch)
print(output)

# %%
#直接加载模型,resnet50_vd
# sys.path.append('/home/work/tire/model_zoo')
# from resnet50_vd import resnet50 #从py文件加载模型
model = torch.load('C:\\Users\\hp\\Desktop\\model_res50vd.pth', map_location=torch.device('cpu'))

# %%
model.eval()
output = model(batch)
print(output)

# %%
# model2 = torchvision.models.mobilenet_v2(pretrained=False)
# num_ftrs = model2.last_channel
# model2.classifier = nn.Sequential(nn.Dropout(0.2), nn.Linear(num_ftrs, 5),)

from my_model_class import myMobileNetV2
model2 = myMobileNetV2()
model2.load_state_dict(torch.load('C:\\Users\\hp\\Desktop\\model_mobilenet_v2_static.pth'))
model2.eval()

# %%
output = model2(batch)
print(output)
