# %%
import numpy as np
import cv2
import time
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
img = Image.open('C:\\Users\\86994\\Desktop\\0.png')

# %%
img = np.array(img)

# %%
print(np.count_nonzero(img==1))
# Out:
# 29964

# %%
plt.imshow(img)

# %%
def get_color_map_list(num_classes):
    """
    Returns the color map for visualizing the segmentation mask,
    which can support arbitrary number of classes.
    Args:
        num_classes (int): Number of classes.
    Returns:
        (list). The color map.
    """

    num_classes += 1
    color_map = num_classes * [0, 0, 0]
    for i in range(0, num_classes):
        j = 0
        lab = i
        while lab:
            color_map[i * 3] |= (((lab >> 0) & 1) << (7 - j))
            color_map[i * 3 + 1] |= (((lab >> 1) & 1) << (7 - j))
            color_map[i * 3 + 2] |= (((lab >> 2) & 1) << (7 - j))
            j += 1
            lab >>= 3
    color_map = color_map[3:]
    return color_map

# %%
color_map = get_color_map_list(256)

# %%
lbl_pil = Image.fromarray(img.astype(np.uint8), mode='P')
lbl_pil.putpalette(color_map)
lbl_pil.save('C:\\Users\\86994\\Desktop\\0\\0.png')

# %%
_path1 =  'C:\\Users\\86994\\Desktop\\0.png'
image = cv2.imread(_path1)
print(image.shape)
# Out:
# (500, 500, 3)

# %%
plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))

# %%
new_image = cv2.applyColorMap(image, cv2.COLORMAP_WINTER)

# %%
cv2.imwrite('C:\\Users\\86994\\Desktop\\0\\0.png', new_image)
# Out:
# True
