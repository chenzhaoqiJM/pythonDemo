# %%
import numpy as np
import cv2
import time
import matplotlib.pyplot as plt
from PIL import Image
import scipy

# %%
def norm(img):
    return (img-img.min())/(img.max()-img.min())

# %%
img = cv2.imread(r'C:\Users\hp\Desktop\1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
R,G,B = img[:,:,0],img[:,:,1],img[:,:,2]
plt.figure(figsize=(9,18))
plt.imshow(R, cmap='gray')

# %%
def func(x):
    return np.math.pow(x, 4)*np.math.pow(1-x, -0.5)

# %%
v, err = scipy.integrate.quad(func, 0, 1)

# %%
_x = np.linspace(0,0.99, 1000)
_y = 1.0/0.8126 * np.math.pow(10, 5) * np.power(_x, 4) * np.power(1+10*_x, -5.5) + 0.3
plt.plot(_x, _y)

# %%
# gama transform
img_f = img.astype(np.float32)/ 255.
# img_f_gama = np.power(img_f, 0.4)
img_f_gama = 1.0/0.8126 * np.math.pow(10, 5) * np.power(img_f, 4) * np.power(1+10*img_f, -5.5) + 0.1

plt.figure(figsize=(9,18))
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(norm(img_f_gama))
