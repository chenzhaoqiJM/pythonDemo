# %%
# !pyinstaller -F -w -i ./source/1.png call.py
# Out:
# 1381 INFO: PyInstaller: 5.6.2
# 1381 INFO: Python: 3.7.15 (conda)
# 1381 INFO: Platform: Windows-10-10.0.19041-SP0
# 1388 INFO: wrote e:\code\git\PaddleSeg\qt_dev\autoCheck\call.spec
# 1403 INFO: UPX is not available.
# 1408 INFO: Extending PYTHONPATH with paths
# ['e:\\code\\git\\PaddleSeg\\qt_dev\\autoCheck']
# 2449 INFO: checking Analysis
# 2613 INFO: Building because e:\code\git\PaddleSeg\qt_dev\autoCheck\sub.py changed
# 2613 INFO: Initializing module dependency graph...
# 2621 INFO: Caching module graph hooks...
# 2674 INFO: Analyzing base_library.zip ...
# 8245 INFO: Loading module hook 'hook-encodings.py' from 'D:\\Anaconda\\envs\\qt_env37\\lib\\site-packages\\PyInstaller\\hooks'...
# 10611 INFO: Loading module hook 'hook-heapq.py' from 'D:\\Anaconda\\envs\\qt_env37\\lib\\site-packages\\PyInstaller\\hooks'...
# 11843 INFO: Loading module hook 'hook-pickle.py' from 'D:\\Anaconda\\envs\\qt_env37\\lib\\site-packages\\PyInstaller\\hooks'...
# ...

# %%
# !python -m PyQt5.uic.pyuic ui_files/auto.ui -o ui_files/auto.py
