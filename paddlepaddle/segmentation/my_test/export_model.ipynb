# %%
# %cd ..
# Out:
# e:\code\git\PaddleSeg

# %%
# !python export.py --config configs/amynet/mulsegmini2xdetail_rust.yml --model_path my.pdparams --save_dir infer_model --without_argmax --input_shape 1 3 512 1024
# Out:
# 2023-05-30 14:12:04 [INFO]	Loaded trained params of model successfully.
# 2023-05-30 14:12:30 [INFO]	Model is saved in infer_model.
# W0530 14:11:57.209904  5472 gpu_resources.cc:61] Please NOTE: device: 0, GPU Compute Capability: 6.1, Driver API Version: 12.0, Runtime API Version: 10.2
# W0530 14:11:57.229380  5472 gpu_resources.cc:91] device: 0, cuDNN Version: 7.6.
# d:\Anaconda\envs\paddle_env\lib\site-packages\paddle\fluid\dygraph\dygraph_to_static\convert_call_func.py:93: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   func_in_dict = func == v

# %%
# !paddle2onnx --model_dir infer_model --model_filename model.pdmodel --params_filename model.pdiparams --opset_version 11 --save_file infer_onnx/mulsegmini2xdetail_rust.onnx
# Out:
# [Paddle2ONNX] Start to parse PaddlePaddle model...
# [Paddle2ONNX] Model file path: infer_model\model.pdmodel
# [Paddle2ONNX] Paramters file path: infer_model\model.pdiparams
# [Paddle2ONNX] Start to parsing Paddle model...
# [Paddle2ONNX] Use opset_version = 11 for ONNX export.
# [Paddle2ONNX] PaddlePaddle model is exported as ONNX format now.
# 2023-05-30 14:12:54 [INFO]	===============Make PaddlePaddle Better!================
# 2023-05-30 14:12:54 [INFO]	A little survey: https://iwenjuan.baidu.com/?code=r8hu2s
