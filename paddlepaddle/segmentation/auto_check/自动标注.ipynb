# %%
import numpy as np
import cv2
import time
import matplotlib.pyplot as plt
from PIL import Image
import os

# %%
img_demo = Image.open(r'C:\Users\hp\Desktop\4_rect\gtFine\1.png')

# %%
data = np.array(img_demo)
data_cv2 = data.astype(np.uint8) * 255
plt.imshow(data_cv2)

# %%
_canny_gray = cv2.Canny(data_cv2, 20,35)
plt.figure(figsize=(9,12))
plt.imshow(_canny_gray, cmap='gray')
